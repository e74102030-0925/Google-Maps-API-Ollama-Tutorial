# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\user\anaconda3\lib\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests) (2025.4.26)

# %%
# !pip install polyline
# Out:
# Collecting polyline
#   Downloading polyline-2.0.3-py3-none-any.whl.metadata (6.5 kB)
# Downloading polyline-2.0.3-py3-none-any.whl (6.0 kB)
# Installing collected packages: polyline
# Successfully installed polyline-2.0.3

# %%
#routes_api_讀取csv計算多重路徑_並存成geojson
import requests
import json
import pandas as pd
import polyline
import os

# === 1. 基本設定 ===
API_KEY = "AIzaSyB3i-mYRdQwbPCYJCDziZVV4-daL66h3HQ" # 輸入你的API KEY
CSV_PATH = "pond_selected_start_end.csv"  # 輸入你的CSV檔名
OUTPUT_GEOJSON = "all_routes.geojson" # 輸入你想輸出的geojson檔名
TRAVEL_MODE = "TWO_WHEELER"  # 可改成：DRIVE / WALK / BICYCLE / TWO_WHEELER

# === 2. 讀取 CSV ===
df = pd.read_csv(CSV_PATH)

# === 3. 初始化 ===
url = "https://routes.googleapis.com/directions/v2:computeRoutes"
headers = {
    "Content-Type": "application/json",
    "X-Goog-Api-Key": API_KEY,
    "X-Goog-FieldMask": "routes.duration,routes.distanceMeters,routes.polyline.encodedPolyline"
}

all_features = []

# === 4. 逐行處理 ===
for i, row in df.iterrows():
    try:
        origin = {"latitude": row["start_lat"], "longitude": row["start_lng"]} # 起點欄位名稱
        destination = {"latitude": row["end_lat"], "longitude": row["end_lng"]} # 終點欄位名稱

        body = {
            "origin": {"location": {"latLng": origin}},
            "destination": {"location": {"latLng": destination}},
            "travelMode": TRAVEL_MODE,
            "routingPreference": "TRAFFIC_UNAWARE", #是否考慮即時交通狀況（TRAFFIC_AWARE 或 TRAFFIC_UNAWARE）
            "computeAlternativeRoutes": False,
            "routeModifiers": {
                "avoidTolls": False,
                "avoidHighways": False,
                "avoidFerries": False
            },
            "languageCode": "zh-TW",
            "units": "METRIC"
        }

        response = requests.post(url, headers=headers, json=body)
        data = response.json()

        if "routes" not in data:
            print(f"無法計算：{row['start']} → {row['end']}")
            continue

        route = data["routes"][0]
        distance = route["distanceMeters"] / 1000
        duration = float(route["duration"].replace("s", "")) / 60  # 轉分鐘
        points = route["polyline"]["encodedPolyline"]
        coords = polyline.decode(points)

        feature = {
            "type": "Feature",
            "geometry": {
                "type": "LineString",
                "coordinates": [[lon, lat] for lat, lon in coords]
            },
            "properties": {
                "start": row["start"],
                "end": row["end"],
                "route_name": row.get("route_name", f"route_{i+1}"),
                "mode": TRAVEL_MODE,
                "distance_km": round(distance, 2),
                "duration_min": round(duration, 1)
            }
        }
        all_features.append(feature)

        print(f"{row['start']} → {row['end']} | {distance:.2f} km, 約 {duration:.1f} 分鐘")

    except Exception as e:
        print(f"第 {i+1} 筆錯誤：{e}")

# === 5. 輸出整合 GeoJSON ===
geojson_data = {"type": "FeatureCollection", "features": all_features}

with open(OUTPUT_GEOJSON, "w", encoding="utf-8") as f:
    json.dump(geojson_data, f, ensure_ascii=False, indent=2)

print(f"\n已完成！共輸出 {len(all_features)} 條路線至：{OUTPUT_GEOJSON}")
# Out:
# 桃園大圳2-1號池 → 石門大圳_茄苳里埤塘公園 | 2.21 km, 約 6.3 分鐘
# 石門大圳_茄苳里埤塘公園 → 石門大圳_中原埤塘生態公園 | 3.38 km, 約 9.8 分鐘
#
# 已完成！共輸出 2 條路線至：all_routes.geojson

# %%
pip install shapely geopy requests pillow
# Out:
# Collecting shapely
#   Downloading shapely-2.1.2-cp313-cp313-win_amd64.whl.metadata (7.1 kB)
# Collecting geopy
#   Downloading geopy-2.4.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: requests in c:\users\user\anaconda3\lib\site-packages (2.32.3)
# Requirement already satisfied: pillow in c:\users\user\anaconda3\lib\site-packages (11.1.0)
# Requirement already satisfied: numpy>=1.21 in c:\users\user\anaconda3\lib\site-packages (from shapely) (2.1.3)
# Collecting geographiclib<3,>=1.52 (from geopy)
#   Downloading geographiclib-2.1-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests) (2025.4.26)
# Downloading shapely-2.1.2-cp313-cp313-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------------------ --------------- 1.0/1.7 MB 4.5 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 4.9 MB/s eta 0:00:00
# Downloading geopy-2.4.1-py3-none-any.whl (125 kB)
# Downloading geographiclib-2.1-py3-none-any.whl (40 kB)
# Installing collected packages: shapely, geographiclib, geopy
#
#    ---------------------------------------- 0/3 [shapely]
#    ------------- -------------------------- 1/3 [geographiclib]
#    ---------------------------------------- 3/3 [geopy]
#
# Successfully installed geographiclib-2.1 geopy-2.4.1 shapely-2.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
#streetview_static_api_讀取geojson_並輸出每個取景點的csv, geojson
import json
import math
import os
import csv
import requests
from shapely.geometry import LineString
from geopy.distance import geodesic
from PIL import Image
from io import BytesIO

API_KEY = "AIzaSyB3i-mYRdQwbPCYJCDziZVV4-daL66h3HQ" # 輸入你的API KEY
GEOJSON_PATH = "all_routes.geojson" # 輸入你的geojson檔名
OUTPUT_DIR = "streetview_images" # 輸入你要存放街景的資料夾名稱
CSV_PATH = "streetview_points.csv" # 輸入你想輸出的csv檔名
GEOJSON_OUT = "streetview_points.geojson" # 輸入你想輸出的geojson檔名

INTERVAL_M = 50 #這裡設定每50公尺一張街景圖
FOV = 90 # Field of View 視野/焦距
PITCH = 0 # 垂直角度（仰角/俯角）

os.makedirs(OUTPUT_DIR, exist_ok=True)

# === 計算方位角 heading ===
def bearing(p1, p2):
    lat1, lon1 = math.radians(p1[0]), math.radians(p1[1])
    lat2, lon2 = math.radians(p2[0]), math.radians(p2[1])
    dlon = lon2 - lon1
    y = math.sin(dlon) * math.cos(lat2)
    x = math.cos(lat1)*math.sin(lat2) - math.sin(lat1)*math.cos(lat2)*math.cos(dlon)
    brng = math.degrees(math.atan2(y, x))
    return (brng + 360) % 360 # 餵給 Street View API 的 heading 參數

# === 計算取樣點 ===
def sample_points(line, interval_m=50):
    shapely_line = LineString([(lon, lat) for lat, lon in line])
    pts = []
    d = 0
    while d < shapely_line.length:
        pt = shapely_line.interpolate(d)
        pts.append((pt.y, pt.x))  # lat, lon
        d += interval_m / 111320
    return pts

# === 找最近有街景的點（自動搜尋半徑） ===
def find_nearest_streetview(lat, lon):
    radii = [0, 10, 20, 30, 50, 80]  # m
    for r in radii:
        url = (
            "https://maps.googleapis.com/maps/api/streetview/metadata"
            f"?location={lat},{lon}&key={API_KEY}"
        )
        res = requests.get(url).json()
        if res.get("status") == "OK":
            sv_lat = res["location"]["lat"]
            sv_lon = res["location"]["lng"]
            dist = geodesic((lat, lon), (sv_lat, sv_lon)).meters
            if dist <= r + 0.1:
                return (sv_lat, sv_lon, dist)
        # 否則換下一個搜尋半徑
    return (None, None, None)

# === 抓街景圖 ===
def fetch_streetview(lat, lon, heading, filename):
    url = (
        "https://maps.googleapis.com/maps/api/streetview"
        f"?size=640x640&location={lat},{lon}&heading={heading}&pitch={PITCH}&fov={FOV}&key={API_KEY}"
    )
    r = requests.get(url)
    if r.status_code == 200:
        img = Image.open(BytesIO(r.content))
        img.save(filename)
        return True
    return False


# === 主要流程：讀路線 → 生成影像＋紀錄 metadata ===
records = []

with open(GEOJSON_PATH, encoding="utf-8") as f:
    data = json.load(f)

for i, feat in enumerate(data["features"]):
    coords = feat["geometry"]["coordinates"]
    route_name = feat["properties"].get("route_name", f"route{i+1}")

    if isinstance(coords[0][0], list):
        coords = [pt for seg in coords for pt in seg]

    line = [(c[1], c[0]) for c in coords]

    samples = sample_points(line, INTERVAL_M)
    print(f"📍 {route_name} 取樣 {len(samples)} 點")

    for j in range(len(samples)-1):
        lat0, lon0 = samples[j]
        next_pt = samples[j+1]

        head = bearing((lat0, lon0), next_pt)

        # 找最近可用街景
        sv_lat, sv_lon, offset = find_nearest_streetview(lat0, lon0)

        if sv_lat is None:
            print(f"❌ 無街景：{lat0}, {lon0}")
            continue

        # 儲存圖片
        fname = os.path.join(OUTPUT_DIR, f"{route_name}_{j+1:03d}.jpg")
        success = fetch_streetview(sv_lat, sv_lon, head, fname)

        if success:
            print(f"✅ {fname}")
        else:
            print(f"⚠️ 街景下載失敗：{sv_lat},{sv_lon}")

        records.append({
            "route_name": route_name,
            "index": j+1,
            "original_lat": lat0,
            "original_lon": lon0,
            "sv_lat": sv_lat,
            "sv_lon": sv_lon,
            "heading": head,
            "pitch": PITCH,
            "fov": FOV,
            "distance_offset_m": offset,
            "image_path": fname
        })

# === 輸出 CSV ===
with open(CSV_PATH, "w", newline="", encoding="utf-8") as f:
    writer = csv.DictWriter(
        f,
        fieldnames=list(records[0].keys())
    )
    writer.writeheader()
    writer.writerows(records)

print(f"已輸出 CSV：{CSV_PATH}")

# === 輸出 GeoJSON ===
geojson = {
    "type": "FeatureCollection",
    "features": []
}

for rec in records:
    geojson["features"].append({
        "type": "Feature",
        "geometry": {
            "type": "Point",
            "coordinates": [rec["sv_lon"], rec["sv_lat"]]
        },
        "properties": rec
    })

with open(GEOJSON_OUT, "w", encoding="utf-8") as f:
    json.dump(geojson, f, ensure_ascii=False, indent=2)

print(f"已輸出 GeoJSON：{GEOJSON_OUT}")
# Out:
# 📍 route_1 取樣 47 點
# ✅ streetview_images\route_1_001.jpg
# ✅ streetview_images\route_1_002.jpg
# ✅ streetview_images\route_1_003.jpg
# ✅ streetview_images\route_1_004.jpg
# ✅ streetview_images\route_1_005.jpg
# ✅ streetview_images\route_1_006.jpg
# ✅ streetview_images\route_1_007.jpg
# ✅ streetview_images\route_1_008.jpg
# ✅ streetview_images\route_1_009.jpg
# ✅ streetview_images\route_1_010.jpg
# ✅ streetview_images\route_1_011.jpg
# ✅ streetview_images\route_1_012.jpg
# ✅ streetview_images\route_1_013.jpg
# ✅ streetview_images\route_1_014.jpg
# ✅ streetview_images\route_1_015.jpg
# ✅ streetview_images\route_1_016.jpg
# ✅ streetview_images\route_1_017.jpg
# ✅ streetview_images\route_1_018.jpg
# ✅ streetview_images\route_1_019.jpg
# ✅ streetview_images\route_1_020.jpg
# ✅ streetview_images\route_1_021.jpg
# ✅ streetview_images\route_1_022.jpg
# ✅ streetview_images\route_1_023.jpg
# ✅ streetview_images\route_1_024.jpg
# ✅ streetview_images\route_1_025.jpg
# ✅ streetview_images\route_1_026.jpg
# ✅ streetview_images\route_1_027.jpg
# ✅ streetview_images\route_1_028.jpg
# ✅ streetview_images\route_1_029.jpg
# ✅ streetview_images\route_1_030.jpg
# ✅ streetview_images\route_1_031.jpg
# ✅ streetview_images\route_1_032.jpg
# ✅ streetview_images\route_1_033.jpg
# ✅ streetview_images\route_1_034.jpg
# ✅ streetview_images\route_1_035.jpg
# ✅ streetview_images\route_1_036.jpg
# ✅ streetview_images\route_1_037.jpg
# ✅ streetview_images\route_1_038.jpg
# ✅ streetview_images\route_1_039.jpg
# ✅ streetview_images\route_1_040.jpg
# ✅ streetview_images\route_1_041.jpg
# ✅ streetview_images\route_1_042.jpg
# ✅ streetview_images\route_1_043.jpg
# ✅ streetview_images\route_1_044.jpg
# ✅ streetview_images\route_1_045.jpg
# ✅ streetview_images\route_1_046.jpg
# 📍 route_2 取樣 73 點
# ✅ streetview_images\route_2_001.jpg
# ✅ streetview_images\route_2_002.jpg
# ✅ streetview_images\route_2_003.jpg
# ✅ streetview_images\route_2_004.jpg
# ✅ streetview_images\route_2_005.jpg
# ✅ streetview_images\route_2_006.jpg
# ✅ streetview_images\route_2_007.jpg
# ✅ streetview_images\route_2_008.jpg
# ✅ streetview_images\route_2_009.jpg
# ✅ streetview_images\route_2_010.jpg
# ✅ streetview_images\route_2_011.jpg
# ✅ streetview_images\route_2_012.jpg
# ✅ streetview_images\route_2_013.jpg
# ✅ streetview_images\route_2_014.jpg
# ✅ streetview_images\route_2_015.jpg
# ✅ streetview_images\route_2_016.jpg
# ✅ streetview_images\route_2_017.jpg
# ✅ streetview_images\route_2_018.jpg
# ✅ streetview_images\route_2_019.jpg
# ✅ streetview_images\route_2_020.jpg
# ✅ streetview_images\route_2_021.jpg
# ✅ streetview_images\route_2_022.jpg
# ✅ streetview_images\route_2_023.jpg
# ✅ streetview_images\route_2_024.jpg
# ✅ streetview_images\route_2_025.jpg
# ✅ streetview_images\route_2_026.jpg
# ✅ streetview_images\route_2_027.jpg
# ✅ streetview_images\route_2_028.jpg
# ✅ streetview_images\route_2_029.jpg
# ✅ streetview_images\route_2_030.jpg
# ✅ streetview_images\route_2_031.jpg
# ✅ streetview_images\route_2_032.jpg
# ✅ streetview_images\route_2_033.jpg
# ✅ streetview_images\route_2_034.jpg
# ✅ streetview_images\route_2_035.jpg
# ✅ streetview_images\route_2_036.jpg
# ✅ streetview_images\route_2_037.jpg
# ✅ streetview_images\route_2_038.jpg
# ✅ streetview_images\route_2_039.jpg
# ✅ streetview_images\route_2_040.jpg
# ✅ streetview_images\route_2_041.jpg
# ✅ streetview_images\route_2_042.jpg
# ✅ streetview_images\route_2_043.jpg
# ✅ streetview_images\route_2_044.jpg
# ✅ streetview_images\route_2_045.jpg
# ✅ streetview_images\route_2_046.jpg
# ✅ streetview_images\route_2_047.jpg
# ✅ streetview_images\route_2_048.jpg
# ✅ streetview_images\route_2_049.jpg
# ✅ streetview_images\route_2_050.jpg
# ✅ streetview_images\route_2_051.jpg
# ✅ streetview_images\route_2_052.jpg
# ✅ streetview_images\route_2_053.jpg
# ✅ streetview_images\route_2_054.jpg
# ✅ streetview_images\route_2_055.jpg
# ✅ streetview_images\route_2_056.jpg
# ✅ streetview_images\route_2_057.jpg
# ✅ streetview_images\route_2_058.jpg
# ✅ streetview_images\route_2_059.jpg
# ✅ streetview_images\route_2_060.jpg
# ✅ streetview_images\route_2_061.jpg
# ✅ streetview_images\route_2_062.jpg
# ✅ streetview_images\route_2_063.jpg
# ✅ streetview_images\route_2_064.jpg
# ✅ streetview_images\route_2_065.jpg
# ✅ streetview_images\route_2_066.jpg
# ✅ streetview_images\route_2_067.jpg
# ✅ streetview_images\route_2_068.jpg
# ✅ streetview_images\route_2_069.jpg
# ✅ streetview_images\route_2_070.jpg
# ✅ streetview_images\route_2_071.jpg
# ✅ streetview_images\route_2_072.jpg
# 已輸出 CSV：streetview_points.csv
# 已輸出 GeoJSON：streetview_points.geojson

# %%
# Llama分析所有照片
import os
import json
import base64
import requests
import csv

HOST = "請輸入你的IP/api/generate"
MODEL = "llama3.2-vision:11b"

IMAGE_FOLDER = "streetview_images" # 輸入存放街景的資料夾名稱
INPUT_GEOJSON = "streetview_points.geojson" # 輸入geojson檔名
OUTPUT_GEOJSON = "streetview_points_with_desc.geojson" # 輸入加入描述後你想要的geojson檔名
OUTPUT_CSV = "streetview_points_with_desc.csv" # 輸入加入描述後你想要的csv檔名


# === 1. 單張圖片 → Llama Vision ===
def query_image(image_path, prompt):
    with open(image_path, "rb") as f:
        img_bytes = f.read()

    img_b64 = base64.b64encode(img_bytes).decode("utf-8")

    data = {
        "model": MODEL,
        "prompt": prompt,
        "images": [img_b64],
        "stream": False
    }

    r = requests.post(HOST, json=data)
    r.raise_for_status()
    return r.json()["response"]


# === 2. 載入原始 GeoJSON（街景點位）# === 
with open(INPUT_GEOJSON, "r", encoding="utf-8") as f:
    base_geo = json.load(f)

# 轉成 dict 方便查找
geo_lookup = {}
for feat in base_geo["features"]:
    img_path = feat["properties"]["image_path"].replace("/", "\\")
    geo_lookup[os.path.basename(img_path)] = feat


# === 3. 準備 CSV（若不存在就建立） === 
csv_exists = os.path.exists(OUTPUT_CSV)

csv_file = open(OUTPUT_CSV, "a", newline="", encoding="utf-8")
csv_writer = csv.writer(csv_file)

if not csv_exists:
    csv_writer.writerow([
        "route_name", "index", "image_path", "lat", "lon", "llama_desc"
    ])


# === 4. 如果已經有輸出的 GeoJSON → 載入，不覆蓋 === 
if os.path.exists(OUTPUT_GEOJSON):
    with open(OUTPUT_GEOJSON, "r", encoding="utf-8") as f:
        out_geo = json.load(f)
else:
    out_geo = {"type": "FeatureCollection", "features": []}


# === 5. 自動搜尋所有街景照片並處理 === 
all_images = sorted([
    f for f in os.listdir(IMAGE_FOLDER)
    if f.lower().endswith((".jpg", ".png", ".jpeg"))
])

print(f"共偵測到 {len(all_images)} 張街景照片，開始分析...\n")


for img in all_images:
    img_path = os.path.join(IMAGE_FOLDER, img)
    print(f"解析：{img} ...")

    # 如果原始 geojson 裡沒有這個點，就跳過
    if img not in geo_lookup:
        print(f"⚠ 原始 GeoJSON 找不到 {img}，跳過")
        continue

    # Llama 分析
    desc = query_image(
        img_path,
        prompt="Please describe this street scene in three sentences: key objects, spatial features, atmosphere." #在這裡輸入你的prompt
    )

    # 將描述寫入對應的 feature
    feature = geo_lookup[img]
    lat = feature["geometry"]["coordinates"][1]
    lon = feature["geometry"]["coordinates"][0]

    # ---- 寫入 CSV ----
    csv_writer.writerow([
        feature["properties"]["route_name"],
        feature["properties"]["index"],
        feature["properties"]["image_path"],
        lat,
        lon,
        desc
    ])

    # ---- 寫入 GeoJSON ----
    new_feature = {
        "type": "Feature",
        "geometry": feature["geometry"],
        "properties": {
            **feature["properties"],
            "llama_desc": desc
        }
    }

    out_geo["features"].append(new_feature)


# === 6. 儲存 GeoJSON === 
with open(OUTPUT_GEOJSON, "w", encoding="utf-8") as f:
    json.dump(out_geo, f, ensure_ascii=False, indent=2)

csv_file.close()

print("\n====== 全部街景分析完成 ======")
print(f"✓ 已更新 CSV：{OUTPUT_CSV}")
print(f"✓ 已更新 GeoJSON：{OUTPUT_GEOJSON}")
# Out:
# 共偵測到 1694 張街景照片，開始分析...
#
# 解析：route_10_001.jpg ...
# 解析：route_10_002.jpg ...
# 解析：route_10_003.jpg ...
# 解析：route_10_004.jpg ...
# 解析：route_10_005.jpg ...
# 解析：route_10_006.jpg ...
# 解析：route_10_007.jpg ...
# 解析：route_10_008.jpg ...
# 解析：route_10_009.jpg ...
# 解析：route_10_010.jpg ...
# 解析：route_10_011.jpg ...
# 解析：route_10_012.jpg ...
# 解析：route_10_013.jpg ...
# 解析：route_10_014.jpg ...
# 解析：route_10_015.jpg ...
# 解析：route_10_016.jpg ...
# 解析：route_10_017.jpg ...
# 解析：route_10_018.jpg ...
# 解析：route_10_019.jpg ...
# 解析：route_10_020.jpg ...
# 解析：route_10_021.jpg ...
# 解析：route_10_022.jpg ...
# 解析：route_10_023.jpg ...
# 解析：route_10_024.jpg ...
# 解析：route_10_025.jpg ...
# 解析：route_10_026.jpg ...
# 解析：route_11_001.jpg ...
# 解析：route_11_002.jpg ...
# 解析：route_11_003.jpg ...
# 解析：route_11_004.jpg ...
# 解析：route_11_005.jpg ...
# 解析：route_11_006.jpg ...
# 解析：route_11_007.jpg ...
# 解析：route_11_008.jpg ...
# 解析：route_11_009.jpg ...
# 解析：route_11_010.jpg ...
# 解析：route_11_011.jpg ...
# 解析：route_11_012.jpg ...
# 解析：route_11_013.jpg ...
# 解析：route_11_014.jpg ...
# 解析：route_11_015.jpg ...
# 解析：route_11_016.jpg ...
# 解析：route_11_017.jpg ...
# 解析：route_11_018.jpg ...
# 解析：route_11_019.jpg ...
# 解析：route_11_020.jpg ...
# 解析：route_11_021.jpg ...
# 解析：route_11_022.jpg ...
# 解析：route_11_023.jpg ...
# 解析：route_11_024.jpg ...
# 解析：route_11_025.jpg ...
# 解析：route_11_026.jpg ...
# 解析：route_11_027.jpg ...
# 解析：route_11_028.jpg ...
# 解析：route_11_029.jpg ...
# 解析：route_11_030.jpg ...
# 解析：route_11_031.jpg ...
# 解析：route_11_032.jpg ...
# 解析：route_11_033.jpg ...
# 解析：route_11_034.jpg ...
# 解析：route_11_035.jpg ...
# 解析：route_11_036.jpg ...
# 解析：route_11_037.jpg ...
# 解析：route_11_038.jpg ...
# 解析：route_11_039.jpg ...
# 解析：route_11_040.jpg ...
# 解析：route_11_041.jpg ...
# 解析：route_11_042.jpg ...
# 解析：route_11_043.jpg ...
# 解析：route_11_044.jpg ...
# 解析：route_11_045.jpg ...
# 解析：route_11_046.jpg ...
# 解析：route_11_047.jpg ...
# 解析：route_11_048.jpg ...
# 解析：route_11_049.jpg ...
# 解析：route_11_050.jpg ...
# 解析：route_11_051.jpg ...
# 解析：route_11_052.jpg ...
# 解析：route_11_053.jpg ...
# 解析：route_11_054.jpg ...
# 解析：route_11_055.jpg ...
# 解析：route_11_056.jpg ...
# 解析：route_11_057.jpg ...
# 解析：route_11_058.jpg ...
# 解析：route_11_059.jpg ...
# 解析：route_11_060.jpg ...
# 解析：route_11_061.jpg ...
# 解析：route_11_062.jpg ...
# 解析：route_11_063.jpg ...
# 解析：route_11_064.jpg ...
# 解析：route_11_065.jpg ...
# 解析：route_11_066.jpg ...
# 解析：route_11_067.jpg ...
# 解析：route_11_068.jpg ...
# 解析：route_11_069.jpg ...
# 解析：route_11_070.jpg ...
# 解析：route_11_071.jpg ...
# 解析：route_11_072.jpg ...
# 解析：route_11_073.jpg ...
# 解析：route_11_074.jpg ...
# 解析：route_11_075.jpg ...
# 解析：route_11_076.jpg ...
# 解析：route_11_077.jpg ...
# 解析：route_11_078.jpg ...
# 解析：route_12_001.jpg ...
# 解析：route_12_002.jpg ...
# 解析：route_12_003.jpg ...
# 解析：route_12_004.jpg ...
# 解析：route_12_005.jpg ...
# 解析：route_12_006.jpg ...
# 解析：route_12_007.jpg ...
# 解析：route_12_008.jpg ...
# 解析：route_12_009.jpg ...
# 解析：route_12_010.jpg ...
# 解析：route_12_011.jpg ...
# 解析：route_12_012.jpg ...
# 解析：route_12_013.jpg ...
# 解析：route_12_014.jpg ...
# 解析：route_12_015.jpg ...
# 解析：route_12_016.jpg ...
# 解析：route_12_017.jpg ...
# 解析：route_12_018.jpg ...
# 解析：route_12_019.jpg ...
# 解析：route_12_020.jpg ...
# 解析：route_12_021.jpg ...
# 解析：route_12_022.jpg ...
# 解析：route_12_023.jpg ...
# 解析：route_12_024.jpg ...
# 解析：route_12_025.jpg ...
# 解析：route_12_026.jpg ...
# 解析：route_12_027.jpg ...
# 解析：route_12_028.jpg ...
# 解析：route_12_029.jpg ...
# 解析：route_12_030.jpg ...
# 解析：route_12_031.jpg ...
# 解析：route_12_032.jpg ...
# 解析：route_12_033.jpg ...
# 解析：route_12_034.jpg ...
# 解析：route_12_035.jpg ...
# 解析：route_12_036.jpg ...
# 解析：route_12_037.jpg ...
# 解析：route_12_038.jpg ...
# 解析：route_12_039.jpg ...
# 解析：route_12_040.jpg ...
# 解析：route_12_041.jpg ...
# 解析：route_12_042.jpg ...
# 解析：route_12_043.jpg ...
# 解析：route_12_044.jpg ...
# 解析：route_12_045.jpg ...
# 解析：route_12_046.jpg ...
# 解析：route_12_047.jpg ...
# 解析：route_12_048.jpg ...
# 解析：route_12_049.jpg ...
# 解析：route_12_050.jpg ...
# 解析：route_12_051.jpg ...
# 解析：route_12_052.jpg ...
# 解析：route_12_053.jpg ...
# 解析：route_12_054.jpg ...
# 解析：route_12_055.jpg ...
# 解析：route_12_056.jpg ...
# 解析：route_12_057.jpg ...
# 解析：route_12_058.jpg ...
# 解析：route_12_059.jpg ...
# 解析：route_12_060.jpg ...
# 解析：route_12_061.jpg ...
# 解析：route_12_062.jpg ...
# 解析：route_12_063.jpg ...
# 解析：route_12_064.jpg ...
# 解析：route_12_065.jpg ...
# 解析：route_12_066.jpg ...
# 解析：route_12_067.jpg ...
# 解析：route_12_068.jpg ...
# 解析：route_12_069.jpg ...
# 解析：route_12_070.jpg ...
# 解析：route_12_071.jpg ...
# 解析：route_12_072.jpg ...
# 解析：route_12_073.jpg ...
# 解析：route_12_074.jpg ...
# 解析：route_13_001.jpg ...
# 解析：route_13_002.jpg ...
# 解析：route_13_003.jpg ...
# 解析：route_13_004.jpg ...
# 解析：route_13_005.jpg ...
# 解析：route_13_006.jpg ...
# 解析：route_13_007.jpg ...
# 解析：route_13_008.jpg ...
# 解析：route_13_009.jpg ...
# 解析：route_13_010.jpg ...
# 解析：route_13_011.jpg ...
# 解析：route_13_012.jpg ...
# 解析：route_13_013.jpg ...
# 解析：route_13_014.jpg ...
# 解析：route_13_015.jpg ...
# 解析：route_13_016.jpg ...
# 解析：route_13_017.jpg ...
# 解析：route_13_018.jpg ...
# 解析：route_13_019.jpg ...
# 解析：route_13_020.jpg ...
# 解析：route_13_021.jpg ...
# 解析：route_13_022.jpg ...
# 解析：route_13_023.jpg ...
# 解析：route_13_024.jpg ...
# 解析：route_13_025.jpg ...
# 解析：route_13_026.jpg ...
# 解析：route_13_027.jpg ...
# 解析：route_14_001.jpg ...
# 解析：route_14_002.jpg ...
# 解析：route_14_003.jpg ...
# 解析：route_14_004.jpg ...
# 解析：route_14_005.jpg ...
# 解析：route_14_006.jpg ...
# 解析：route_14_007.jpg ...
# 解析：route_14_008.jpg ...
# 解析：route_14_009.jpg ...
# 解析：route_14_010.jpg ...
# 解析：route_14_011.jpg ...
# 解析：route_14_012.jpg ...
# 解析：route_14_013.jpg ...
# 解析：route_14_014.jpg ...
# 解析：route_14_015.jpg ...
# 解析：route_14_016.jpg ...
# 解析：route_14_017.jpg ...
# 解析：route_14_018.jpg ...
# 解析：route_14_019.jpg ...
# 解析：route_14_020.jpg ...
# 解析：route_14_021.jpg ...
# 解析：route_14_022.jpg ...
# 解析：route_14_023.jpg ...
# 解析：route_14_024.jpg ...
# 解析：route_14_025.jpg ...
# 解析：route_14_026.jpg ...
# 解析：route_14_027.jpg ...
# 解析：route_14_028.jpg ...
# 解析：route_14_029.jpg ...
# 解析：route_14_030.jpg ...
# 解析：route_14_031.jpg ...
# 解析：route_14_032.jpg ...
# 解析：route_14_033.jpg ...
# 解析：route_14_034.jpg ...
# 解析：route_14_035.jpg ...
# 解析：route_14_036.jpg ...
# 解析：route_14_037.jpg ...
# 解析：route_14_038.jpg ...
# 解析：route_14_039.jpg ...
# 解析：route_14_040.jpg ...
# 解析：route_14_041.jpg ...
# 解析：route_14_042.jpg ...
# 解析：route_14_043.jpg ...
# 解析：route_14_044.jpg ...
# 解析：route_14_045.jpg ...
# 解析：route_14_046.jpg ...
# 解析：route_14_047.jpg ...
# 解析：route_14_048.jpg ...
# 解析：route_14_049.jpg ...
# 解析：route_14_050.jpg ...
# 解析：route_14_051.jpg ...
# 解析：route_14_052.jpg ...
# 解析：route_14_053.jpg ...
# 解析：route_14_054.jpg ...
# 解析：route_14_055.jpg ...
# 解析：route_14_056.jpg ...
# 解析：route_14_057.jpg ...
# 解析：route_14_058.jpg ...
# 解析：route_14_059.jpg ...
# 解析：route_14_060.jpg ...
# 解析：route_15_001.jpg ...
# 解析：route_15_002.jpg ...
# 解析：route_15_003.jpg ...
# 解析：route_15_004.jpg ...
# 解析：route_15_005.jpg ...
# 解析：route_15_006.jpg ...
# 解析：route_15_007.jpg ...
# 解析：route_15_008.jpg ...
# 解析：route_15_009.jpg ...
# 解析：route_15_010.jpg ...
# 解析：route_15_011.jpg ...
# 解析：route_15_012.jpg ...
# 解析：route_15_013.jpg ...
# 解析：route_15_014.jpg ...
# 解析：route_15_015.jpg ...
# 解析：route_15_016.jpg ...
# 解析：route_15_017.jpg ...
# 解析：route_15_018.jpg ...
# 解析：route_15_019.jpg ...
# 解析：route_15_020.jpg ...
# 解析：route_15_021.jpg ...
# 解析：route_15_022.jpg ...
# 解析：route_15_023.jpg ...
# 解析：route_15_024.jpg ...
# 解析：route_15_025.jpg ...
# 解析：route_15_026.jpg ...
# 解析：route_15_027.jpg ...
# 解析：route_15_028.jpg ...
# 解析：route_15_029.jpg ...
# 解析：route_16_005.jpg ...
# 解析：route_16_006.jpg ...
# 解析：route_16_007.jpg ...
# 解析：route_16_008.jpg ...
# 解析：route_16_009.jpg ...
# 解析：route_16_010.jpg ...
# 解析：route_16_011.jpg ...
# 解析：route_16_012.jpg ...
# 解析：route_16_013.jpg ...
# 解析：route_16_014.jpg ...
# 解析：route_16_015.jpg ...
# 解析：route_16_016.jpg ...
# 解析：route_16_017.jpg ...
# 解析：route_16_018.jpg ...
# 解析：route_16_019.jpg ...
# 解析：route_16_020.jpg ...
# 解析：route_16_021.jpg ...
# 解析：route_16_022.jpg ...
# 解析：route_16_023.jpg ...
# 解析：route_16_024.jpg ...
# 解析：route_17_001.jpg ...
# 解析：route_17_002.jpg ...
# 解析：route_17_003.jpg ...
# 解析：route_17_004.jpg ...
# 解析：route_17_005.jpg ...
# 解析：route_17_006.jpg ...
# 解析：route_17_007.jpg ...
# 解析：route_17_008.jpg ...
# 解析：route_17_009.jpg ...
# 解析：route_17_010.jpg ...
# 解析：route_17_011.jpg ...
# 解析：route_17_012.jpg ...
# 解析：route_17_013.jpg ...
# 解析：route_17_014.jpg ...
# 解析：route_17_015.jpg ...
# 解析：route_17_016.jpg ...
# 解析：route_17_017.jpg ...
# 解析：route_17_018.jpg ...
# 解析：route_17_019.jpg ...
# 解析：route_17_020.jpg ...
# 解析：route_17_021.jpg ...
# 解析：route_17_022.jpg ...
# 解析：route_17_023.jpg ...
# 解析：route_17_024.jpg ...
# 解析：route_17_025.jpg ...
# 解析：route_17_026.jpg ...
# 解析：route_17_027.jpg ...
# 解析：route_17_028.jpg ...
# 解析：route_17_029.jpg ...
# 解析：route_17_030.jpg ...
# 解析：route_17_031.jpg ...
# 解析：route_17_032.jpg ...
# 解析：route_17_033.jpg ...
# 解析：route_17_034.jpg ...
# 解析：route_17_035.jpg ...
# 解析：route_17_036.jpg ...
# 解析：route_17_037.jpg ...
# 解析：route_17_038.jpg ...
# 解析：route_17_039.jpg ...
# 解析：route_17_040.jpg ...
# 解析：route_17_041.jpg ...
# 解析：route_17_042.jpg ...
# 解析：route_17_043.jpg ...
# 解析：route_17_044.jpg ...
# 解析：route_17_045.jpg ...
# 解析：route_17_046.jpg ...
# 解析：route_18_001.jpg ...
# 解析：route_18_002.jpg ...
# 解析：route_18_003.jpg ...
# 解析：route_18_004.jpg ...
# 解析：route_18_005.jpg ...
# 解析：route_18_006.jpg ...
# 解析：route_18_007.jpg ...
# 解析：route_18_008.jpg ...
# 解析：route_18_009.jpg ...
# 解析：route_18_010.jpg ...
# 解析：route_18_011.jpg ...
# 解析：route_18_012.jpg ...
# 解析：route_18_013.jpg ...
# 解析：route_18_014.jpg ...
# 解析：route_18_015.jpg ...
# 解析：route_18_016.jpg ...
# 解析：route_18_017.jpg ...
# 解析：route_18_018.jpg ...
# 解析：route_18_019.jpg ...
# 解析：route_18_020.jpg ...
# 解析：route_18_021.jpg ...
# 解析：route_18_022.jpg ...
# 解析：route_18_023.jpg ...
# 解析：route_18_024.jpg ...
# 解析：route_18_025.jpg ...
# 解析：route_18_026.jpg ...
# 解析：route_18_027.jpg ...
# 解析：route_18_028.jpg ...
# 解析：route_18_029.jpg ...
# 解析：route_18_030.jpg ...
# 解析：route_18_031.jpg ...
# 解析：route_18_032.jpg ...
# 解析：route_18_033.jpg ...
# 解析：route_18_034.jpg ...
# 解析：route_18_035.jpg ...
# 解析：route_18_036.jpg ...
# 解析：route_18_037.jpg ...
# 解析：route_18_038.jpg ...
# 解析：route_18_039.jpg ...
# 解析：route_18_040.jpg ...
# 解析：route_18_041.jpg ...
# 解析：route_18_042.jpg ...
# 解析：route_18_043.jpg ...
# 解析：route_18_044.jpg ...
# 解析：route_18_045.jpg ...
# 解析：route_18_046.jpg ...
# 解析：route_18_047.jpg ...
# 解析：route_18_048.jpg ...
# 解析：route_18_049.jpg ...
# 解析：route_18_050.jpg ...
# 解析：route_18_051.jpg ...
# 解析：route_18_052.jpg ...
# 解析：route_18_053.jpg ...
# 解析：route_18_054.jpg ...
# 解析：route_18_055.jpg ...
# 解析：route_18_056.jpg ...
# 解析：route_18_057.jpg ...
# 解析：route_18_058.jpg ...
# 解析：route_18_059.jpg ...
# 解析：route_18_060.jpg ...
# 解析：route_18_061.jpg ...
# 解析：route_18_062.jpg ...
# 解析：route_18_063.jpg ...
# 解析：route_18_064.jpg ...
# 解析：route_18_065.jpg ...
# 解析：route_18_066.jpg ...
# 解析：route_18_067.jpg ...
# 解析：route_18_068.jpg ...
# 解析：route_18_069.jpg ...
# 解析：route_18_070.jpg ...
# 解析：route_18_071.jpg ...
# 解析：route_18_072.jpg ...
# 解析：route_19_001.jpg ...
# 解析：route_19_002.jpg ...
# 解析：route_19_003.jpg ...
# 解析：route_19_004.jpg ...
# 解析：route_19_005.jpg ...
# 解析：route_19_006.jpg ...
# 解析：route_19_007.jpg ...
# 解析：route_19_008.jpg ...
# 解析：route_19_009.jpg ...
# 解析：route_19_010.jpg ...
# 解析：route_19_011.jpg ...
# 解析：route_19_012.jpg ...
# 解析：route_19_013.jpg ...
# 解析：route_19_014.jpg ...
# 解析：route_19_015.jpg ...
# 解析：route_19_016.jpg ...
# 解析：route_19_017.jpg ...
# 解析：route_19_018.jpg ...
# 解析：route_19_019.jpg ...
# 解析：route_19_020.jpg ...
# 解析：route_19_021.jpg ...
# 解析：route_19_022.jpg ...
# 解析：route_19_023.jpg ...
# 解析：route_19_024.jpg ...
# 解析：route_19_025.jpg ...
# 解析：route_19_026.jpg ...
# 解析：route_19_027.jpg ...
# 解析：route_19_028.jpg ...
# 解析：route_19_029.jpg ...
# 解析：route_19_030.jpg ...
# 解析：route_19_031.jpg ...
# 解析：route_19_032.jpg ...
# 解析：route_19_033.jpg ...
# 解析：route_19_034.jpg ...
# 解析：route_19_035.jpg ...
# 解析：route_19_036.jpg ...
# 解析：route_19_037.jpg ...
# 解析：route_19_038.jpg ...
# 解析：route_19_039.jpg ...
# 解析：route_19_040.jpg ...
# 解析：route_19_041.jpg ...
# 解析：route_19_042.jpg ...
# 解析：route_19_043.jpg ...
# 解析：route_19_044.jpg ...
# 解析：route_19_045.jpg ...
# 解析：route_19_046.jpg ...
# 解析：route_19_047.jpg ...
# 解析：route_19_048.jpg ...
# 解析：route_19_049.jpg ...
# 解析：route_19_050.jpg ...
# 解析：route_19_051.jpg ...
# 解析：route_19_052.jpg ...
# 解析：route_19_053.jpg ...
# 解析：route_19_054.jpg ...
# 解析：route_19_055.jpg ...
# 解析：route_19_056.jpg ...
# 解析：route_19_057.jpg ...
# 解析：route_19_058.jpg ...
# 解析：route_19_059.jpg ...
# 解析：route_19_060.jpg ...
# 解析：route_19_061.jpg ...
# 解析：route_19_062.jpg ...
# 解析：route_19_063.jpg ...
# 解析：route_19_064.jpg ...
# 解析：route_19_065.jpg ...
# 解析：route_19_066.jpg ...
# 解析：route_19_067.jpg ...
# 解析：route_19_068.jpg ...
# 解析：route_19_069.jpg ...
# 解析：route_19_070.jpg ...
# 解析：route_19_071.jpg ...
# 解析：route_19_072.jpg ...
# 解析：route_19_073.jpg ...
# 解析：route_19_074.jpg ...
# 解析：route_19_075.jpg ...
# 解析：route_19_076.jpg ...
# 解析：route_19_077.jpg ...
# 解析：route_19_078.jpg ...
# 解析：route_19_079.jpg ...
# 解析：route_19_080.jpg ...
# 解析：route_19_081.jpg ...
# 解析：route_19_082.jpg ...
# 解析：route_19_083.jpg ...
# 解析：route_19_084.jpg ...
# 解析：route_19_085.jpg ...
# 解析：route_19_086.jpg ...
# 解析：route_19_087.jpg ...
# 解析：route_19_088.jpg ...
# 解析：route_19_089.jpg ...
# 解析：route_19_090.jpg ...
# 解析：route_19_091.jpg ...
# 解析：route_19_092.jpg ...
# 解析：route_19_093.jpg ...
# 解析：route_19_094.jpg ...
# 解析：route_19_095.jpg ...
# 解析：route_1_001.jpg ...
# 解析：route_1_002.jpg ...
# 解析：route_1_003.jpg ...
# 解析：route_1_004.jpg ...
# 解析：route_1_005.jpg ...
# 解析：route_1_006.jpg ...
# 解析：route_1_007.jpg ...
# 解析：route_1_008.jpg ...
# 解析：route_1_009.jpg ...
# 解析：route_1_010.jpg ...
# 解析：route_1_011.jpg ...
# 解析：route_1_012.jpg ...
# 解析：route_1_013.jpg ...
# 解析：route_1_014.jpg ...
# 解析：route_1_015.jpg ...
# 解析：route_1_016.jpg ...
# 解析：route_1_017.jpg ...
# 解析：route_1_018.jpg ...
# 解析：route_1_019.jpg ...
# 解析：route_1_020.jpg ...
# 解析：route_1_021.jpg ...
# 解析：route_1_022.jpg ...
# 解析：route_1_023.jpg ...
# 解析：route_1_024.jpg ...
# 解析：route_1_025.jpg ...
# 解析：route_1_026.jpg ...
# 解析：route_1_027.jpg ...
# 解析：route_1_028.jpg ...
# 解析：route_1_029.jpg ...
# 解析：route_1_030.jpg ...
# 解析：route_1_031.jpg ...
# 解析：route_1_032.jpg ...
# 解析：route_1_033.jpg ...
# 解析：route_1_034.jpg ...
# 解析：route_1_035.jpg ...
# 解析：route_1_036.jpg ...
# 解析：route_1_037.jpg ...
# 解析：route_1_038.jpg ...
# 解析：route_1_039.jpg ...
# 解析：route_1_040.jpg ...
# 解析：route_1_041.jpg ...
# 解析：route_1_042.jpg ...
# 解析：route_1_043.jpg ...
# 解析：route_1_044.jpg ...
# 解析：route_1_045.jpg ...
# 解析：route_1_046.jpg ...
# 解析：route_1_047.jpg ...
# 解析：route_1_048.jpg ...
# 解析：route_1_049.jpg ...
# 解析：route_1_050.jpg ...
# 解析：route_1_051.jpg ...
# 解析：route_1_052.jpg ...
# 解析：route_1_053.jpg ...
# 解析：route_1_054.jpg ...
# 解析：route_1_055.jpg ...
# 解析：route_1_056.jpg ...
# 解析：route_1_057.jpg ...
# 解析：route_1_058.jpg ...
# 解析：route_1_059.jpg ...
# 解析：route_1_060.jpg ...
# 解析：route_1_061.jpg ...
# 解析：route_1_062.jpg ...
# 解析：route_1_063.jpg ...
# 解析：route_1_064.jpg ...
# 解析：route_1_065.jpg ...
# 解析：route_1_066.jpg ...
# 解析：route_1_067.jpg ...
# 解析：route_1_068.jpg ...
# 解析：route_1_069.jpg ...
# 解析：route_1_070.jpg ...
# 解析：route_1_071.jpg ...
# 解析：route_1_072.jpg ...
# 解析：route_1_073.jpg ...
# 解析：route_1_074.jpg ...
# 解析：route_1_075.jpg ...
# 解析：route_1_076.jpg ...
# 解析：route_1_077.jpg ...
# 解析：route_20_001.jpg ...
# 解析：route_20_002.jpg ...
# 解析：route_20_003.jpg ...
# 解析：route_20_004.jpg ...
# 解析：route_20_005.jpg ...
# 解析：route_20_006.jpg ...
# 解析：route_20_007.jpg ...
# 解析：route_20_008.jpg ...
# 解析：route_20_009.jpg ...
# 解析：route_20_010.jpg ...
# 解析：route_20_011.jpg ...
# 解析：route_20_012.jpg ...
# 解析：route_20_013.jpg ...
# 解析：route_20_014.jpg ...
# 解析：route_20_015.jpg ...
# 解析：route_20_016.jpg ...
# 解析：route_20_017.jpg ...
# 解析：route_20_018.jpg ...
# 解析：route_20_019.jpg ...
# 解析：route_20_020.jpg ...
# 解析：route_20_021.jpg ...
# 解析：route_20_022.jpg ...
# 解析：route_20_023.jpg ...
# 解析：route_20_024.jpg ...
# 解析：route_20_025.jpg ...
# 解析：route_20_026.jpg ...
# 解析：route_20_027.jpg ...
# 解析：route_20_028.jpg ...
# 解析：route_20_029.jpg ...
# 解析：route_20_030.jpg ...
# 解析：route_20_031.jpg ...
# 解析：route_20_032.jpg ...
# 解析：route_20_033.jpg ...
# 解析：route_20_034.jpg ...
# 解析：route_20_035.jpg ...
# 解析：route_20_036.jpg ...
# 解析：route_20_037.jpg ...
# 解析：route_20_038.jpg ...
# 解析：route_20_039.jpg ...
# 解析：route_20_040.jpg ...
# 解析：route_20_041.jpg ...
# 解析：route_20_042.jpg ...
# 解析：route_20_043.jpg ...
# 解析：route_20_044.jpg ...
# 解析：route_20_045.jpg ...
# 解析：route_20_046.jpg ...
# 解析：route_20_047.jpg ...
# 解析：route_20_048.jpg ...
# 解析：route_20_049.jpg ...
# 解析：route_20_050.jpg ...
# 解析：route_20_051.jpg ...
# 解析：route_20_052.jpg ...
# 解析：route_20_053.jpg ...
# 解析：route_21_001.jpg ...
# 解析：route_21_002.jpg ...
# 解析：route_21_003.jpg ...
# 解析：route_21_004.jpg ...
# 解析：route_21_005.jpg ...
# 解析：route_21_006.jpg ...
# 解析：route_21_007.jpg ...
# 解析：route_21_008.jpg ...
# 解析：route_21_009.jpg ...
# 解析：route_21_010.jpg ...
# 解析：route_21_011.jpg ...
# 解析：route_21_012.jpg ...
# 解析：route_21_013.jpg ...
# 解析：route_21_014.jpg ...
# 解析：route_21_015.jpg ...
# 解析：route_21_016.jpg ...
# 解析：route_21_017.jpg ...
# 解析：route_21_018.jpg ...
# 解析：route_21_019.jpg ...
# 解析：route_21_020.jpg ...
# 解析：route_21_021.jpg ...
# 解析：route_21_022.jpg ...
# 解析：route_21_023.jpg ...
# 解析：route_21_024.jpg ...
# 解析：route_21_025.jpg ...
# 解析：route_21_026.jpg ...
# 解析：route_21_027.jpg ...
# 解析：route_21_028.jpg ...
# 解析：route_21_029.jpg ...
# 解析：route_21_030.jpg ...
# 解析：route_21_031.jpg ...
# 解析：route_21_032.jpg ...
# 解析：route_21_033.jpg ...
# 解析：route_21_034.jpg ...
# 解析：route_21_035.jpg ...
# 解析：route_21_036.jpg ...
# 解析：route_21_037.jpg ...
# 解析：route_21_038.jpg ...
# 解析：route_21_039.jpg ...
# 解析：route_21_040.jpg ...
# 解析：route_21_041.jpg ...
# 解析：route_21_042.jpg ...
# 解析：route_21_043.jpg ...
# 解析：route_21_044.jpg ...
# 解析：route_21_045.jpg ...
# 解析：route_21_046.jpg ...
# 解析：route_21_047.jpg ...
# 解析：route_21_048.jpg ...
# 解析：route_21_049.jpg ...
# 解析：route_21_050.jpg ...
# 解析：route_21_051.jpg ...
# 解析：route_21_052.jpg ...
# 解析：route_21_053.jpg ...
# 解析：route_21_054.jpg ...
# 解析：route_21_055.jpg ...
# 解析：route_21_056.jpg ...
# 解析：route_21_057.jpg ...
# 解析：route_21_058.jpg ...
# 解析：route_21_059.jpg ...
# 解析：route_21_060.jpg ...
# 解析：route_21_061.jpg ...
# 解析：route_21_062.jpg ...
# 解析：route_21_063.jpg ...
# 解析：route_21_064.jpg ...
# 解析：route_21_065.jpg ...
# 解析：route_21_066.jpg ...
# 解析：route_21_067.jpg ...
# 解析：route_21_068.jpg ...
# 解析：route_21_069.jpg ...
# 解析：route_21_070.jpg ...
# 解析：route_21_071.jpg ...
# 解析：route_21_072.jpg ...
# 解析：route_21_073.jpg ...
# 解析：route_21_074.jpg ...
# 解析：route_21_075.jpg ...
# 解析：route_21_076.jpg ...
# 解析：route_21_077.jpg ...
# 解析：route_21_078.jpg ...
# 解析：route_21_079.jpg ...
# 解析：route_21_080.jpg ...
# 解析：route_21_081.jpg ...
# 解析：route_21_082.jpg ...
# 解析：route_21_083.jpg ...
# 解析：route_21_084.jpg ...
# 解析：route_21_085.jpg ...
# 解析：route_21_086.jpg ...
# 解析：route_21_087.jpg ...
# 解析：route_21_088.jpg ...
# 解析：route_21_089.jpg ...
# 解析：route_21_090.jpg ...
# 解析：route_21_091.jpg ...
# 解析：route_21_092.jpg ...
# 解析：route_21_093.jpg ...
# 解析：route_21_094.jpg ...
# 解析：route_21_095.jpg ...
# 解析：route_21_096.jpg ...
# 解析：route_21_097.jpg ...
# 解析：route_21_098.jpg ...
# 解析：route_21_099.jpg ...
# 解析：route_22_001.jpg ...
# 解析：route_22_002.jpg ...
# 解析：route_22_003.jpg ...
# 解析：route_22_004.jpg ...
# 解析：route_22_005.jpg ...
# 解析：route_22_006.jpg ...
# 解析：route_22_007.jpg ...
# 解析：route_22_008.jpg ...
# 解析：route_22_009.jpg ...
# 解析：route_22_010.jpg ...
# 解析：route_22_011.jpg ...
# 解析：route_22_012.jpg ...
# 解析：route_22_013.jpg ...
# 解析：route_22_014.jpg ...
# 解析：route_22_015.jpg ...
# 解析：route_22_016.jpg ...
# 解析：route_22_017.jpg ...
# 解析：route_22_018.jpg ...
# 解析：route_22_019.jpg ...
# 解析：route_22_020.jpg ...
# 解析：route_22_021.jpg ...
# 解析：route_22_022.jpg ...
# 解析：route_22_023.jpg ...
# 解析：route_22_024.jpg ...
# 解析：route_22_025.jpg ...
# 解析：route_22_026.jpg ...
# 解析：route_22_027.jpg ...
# 解析：route_22_028.jpg ...
# 解析：route_22_029.jpg ...
# 解析：route_22_030.jpg ...
# 解析：route_22_031.jpg ...
# 解析：route_22_032.jpg ...
# 解析：route_22_033.jpg ...
# 解析：route_22_034.jpg ...
# 解析：route_22_035.jpg ...
# 解析：route_22_036.jpg ...
# 解析：route_22_037.jpg ...
# 解析：route_22_038.jpg ...
# 解析：route_22_039.jpg ...
# 解析：route_22_040.jpg ...
# 解析：route_22_041.jpg ...
# 解析：route_22_042.jpg ...
# 解析：route_22_043.jpg ...
# 解析：route_22_044.jpg ...
# 解析：route_22_045.jpg ...
# 解析：route_22_046.jpg ...
# 解析：route_22_047.jpg ...
# 解析：route_22_048.jpg ...
# 解析：route_22_056.jpg ...
# 解析：route_23_001.jpg ...
# 解析：route_23_002.jpg ...
# 解析：route_23_003.jpg ...
# 解析：route_23_004.jpg ...
# 解析：route_23_011.jpg ...
# 解析：route_23_012.jpg ...
# 解析：route_23_013.jpg ...
# 解析：route_23_014.jpg ...
# 解析：route_23_015.jpg ...
# 解析：route_23_016.jpg ...
# 解析：route_23_017.jpg ...
# 解析：route_23_018.jpg ...
# 解析：route_23_019.jpg ...
# 解析：route_23_020.jpg ...
# 解析：route_23_021.jpg ...
# 解析：route_23_022.jpg ...
# 解析：route_23_023.jpg ...
# 解析：route_23_024.jpg ...
# 解析：route_23_025.jpg ...
# 解析：route_23_026.jpg ...
# 解析：route_23_027.jpg ...
# 解析：route_23_028.jpg ...
# 解析：route_23_029.jpg ...
# 解析：route_23_030.jpg ...
# 解析：route_23_031.jpg ...
# 解析：route_23_032.jpg ...
# 解析：route_23_033.jpg ...
# 解析：route_23_034.jpg ...
# 解析：route_23_035.jpg ...
# 解析：route_23_036.jpg ...
# 解析：route_23_037.jpg ...
# 解析：route_23_038.jpg ...
# 解析：route_23_039.jpg ...
# 解析：route_23_040.jpg ...
# 解析：route_23_041.jpg ...
# 解析：route_23_042.jpg ...
# 解析：route_23_043.jpg ...
# 解析：route_23_044.jpg ...
# 解析：route_23_045.jpg ...
# 解析：route_23_046.jpg ...
# 解析：route_23_047.jpg ...
# 解析：route_23_048.jpg ...
# 解析：route_23_049.jpg ...
# 解析：route_23_050.jpg ...
# 解析：route_23_051.jpg ...
# 解析：route_23_052.jpg ...
# 解析：route_23_053.jpg ...
# 解析：route_23_054.jpg ...
# 解析：route_24_001.jpg ...
# 解析：route_24_002.jpg ...
# 解析：route_24_003.jpg ...
# 解析：route_24_004.jpg ...
# 解析：route_24_005.jpg ...
# 解析：route_24_006.jpg ...
# 解析：route_24_007.jpg ...
# 解析：route_24_008.jpg ...
# 解析：route_24_009.jpg ...
# 解析：route_24_010.jpg ...
# 解析：route_24_011.jpg ...
# 解析：route_24_012.jpg ...
# 解析：route_24_013.jpg ...
# 解析：route_24_014.jpg ...
# 解析：route_24_015.jpg ...
# 解析：route_24_016.jpg ...
# 解析：route_24_017.jpg ...
# 解析：route_24_018.jpg ...
# 解析：route_24_019.jpg ...
# 解析：route_24_020.jpg ...
# 解析：route_24_021.jpg ...
# 解析：route_24_022.jpg ...
# 解析：route_24_023.jpg ...
# 解析：route_24_024.jpg ...
# 解析：route_24_025.jpg ...
# 解析：route_25_001.jpg ...
# 解析：route_25_002.jpg ...
# 解析：route_25_003.jpg ...
# 解析：route_25_004.jpg ...
# 解析：route_25_005.jpg ...
# 解析：route_25_006.jpg ...
# 解析：route_25_007.jpg ...
# 解析：route_25_008.jpg ...
# 解析：route_25_009.jpg ...
# 解析：route_25_010.jpg ...
# 解析：route_25_011.jpg ...
# 解析：route_25_012.jpg ...
# 解析：route_25_013.jpg ...
# 解析：route_25_014.jpg ...
# 解析：route_25_015.jpg ...
# 解析：route_25_016.jpg ...
# 解析：route_25_017.jpg ...
# 解析：route_25_018.jpg ...
# 解析：route_25_019.jpg ...
# 解析：route_25_020.jpg ...
# 解析：route_25_021.jpg ...
# 解析：route_25_022.jpg ...
# 解析：route_25_023.jpg ...
# 解析：route_25_024.jpg ...
# 解析：route_25_025.jpg ...
# 解析：route_25_026.jpg ...
# 解析：route_25_027.jpg ...
# 解析：route_25_028.jpg ...
# 解析：route_25_029.jpg ...
# 解析：route_25_030.jpg ...
# 解析：route_25_031.jpg ...
# 解析：route_25_032.jpg ...
# 解析：route_25_033.jpg ...
# 解析：route_25_034.jpg ...
# 解析：route_25_035.jpg ...
# 解析：route_25_036.jpg ...
# 解析：route_25_037.jpg ...
# 解析：route_25_038.jpg ...
# 解析：route_26_001.jpg ...
# 解析：route_26_002.jpg ...
# 解析：route_26_003.jpg ...
# 解析：route_26_004.jpg ...
# 解析：route_26_005.jpg ...
# 解析：route_26_006.jpg ...
# 解析：route_26_007.jpg ...
# 解析：route_26_008.jpg ...
# 解析：route_26_009.jpg ...
# 解析：route_26_010.jpg ...
# 解析：route_26_011.jpg ...
# 解析：route_27_001.jpg ...
# 解析：route_27_002.jpg ...
# 解析：route_27_003.jpg ...
# 解析：route_27_004.jpg ...
# 解析：route_27_005.jpg ...
# 解析：route_27_006.jpg ...
# 解析：route_27_007.jpg ...
# 解析：route_27_008.jpg ...
# 解析：route_27_009.jpg ...
# 解析：route_27_010.jpg ...
# 解析：route_27_011.jpg ...
# 解析：route_27_012.jpg ...
# 解析：route_27_013.jpg ...
# 解析：route_27_014.jpg ...
# 解析：route_27_015.jpg ...
# 解析：route_27_016.jpg ...
# 解析：route_27_017.jpg ...
# 解析：route_27_018.jpg ...
# 解析：route_27_019.jpg ...
# 解析：route_27_020.jpg ...
# 解析：route_27_021.jpg ...
# 解析：route_27_022.jpg ...
# 解析：route_27_023.jpg ...
# 解析：route_27_024.jpg ...
# 解析：route_27_025.jpg ...
# 解析：route_27_026.jpg ...
# 解析：route_27_027.jpg ...
# 解析：route_27_028.jpg ...
# 解析：route_27_029.jpg ...
# 解析：route_27_030.jpg ...
# 解析：route_27_031.jpg ...
# 解析：route_27_032.jpg ...
# 解析：route_27_033.jpg ...
# 解析：route_27_034.jpg ...
# 解析：route_27_035.jpg ...
# 解析：route_27_036.jpg ...
# 解析：route_27_037.jpg ...
# 解析：route_27_038.jpg ...
# 解析：route_27_039.jpg ...
# 解析：route_27_040.jpg ...
# 解析：route_27_041.jpg ...
# 解析：route_27_042.jpg ...
# 解析：route_27_043.jpg ...
# 解析：route_27_044.jpg ...
# 解析：route_27_045.jpg ...
# 解析：route_27_046.jpg ...
# 解析：route_27_047.jpg ...
# 解析：route_27_048.jpg ...
# 解析：route_27_049.jpg ...
# 解析：route_27_050.jpg ...
# 解析：route_27_051.jpg ...
# 解析：route_27_052.jpg ...
# 解析：route_27_053.jpg ...
# 解析：route_27_054.jpg ...
# 解析：route_27_055.jpg ...
# 解析：route_27_056.jpg ...
# 解析：route_27_057.jpg ...
# 解析：route_27_058.jpg ...
# 解析：route_27_059.jpg ...
# 解析：route_27_060.jpg ...
# 解析：route_27_061.jpg ...
# 解析：route_27_062.jpg ...
# 解析：route_27_063.jpg ...
# 解析：route_27_064.jpg ...
# 解析：route_27_065.jpg ...
# 解析：route_27_066.jpg ...
# 解析：route_27_067.jpg ...
# 解析：route_27_068.jpg ...
# 解析：route_27_069.jpg ...
# 解析：route_27_070.jpg ...
# 解析：route_27_071.jpg ...
# 解析：route_27_072.jpg ...
# 解析：route_27_073.jpg ...
# 解析：route_27_074.jpg ...
# 解析：route_27_075.jpg ...
# 解析：route_27_076.jpg ...
# 解析：route_27_077.jpg ...
# 解析：route_27_078.jpg ...
# 解析：route_27_079.jpg ...
# 解析：route_27_080.jpg ...
# 解析：route_27_081.jpg ...
# 解析：route_27_082.jpg ...
# 解析：route_27_083.jpg ...
# 解析：route_27_084.jpg ...
# 解析：route_27_085.jpg ...
# 解析：route_27_086.jpg ...
# 解析：route_2_001.jpg ...
# 解析：route_2_002.jpg ...
# 解析：route_2_003.jpg ...
# 解析：route_2_004.jpg ...
# 解析：route_2_005.jpg ...
# 解析：route_2_006.jpg ...
# 解析：route_2_007.jpg ...
# 解析：route_2_008.jpg ...
# 解析：route_2_009.jpg ...
# 解析：route_2_010.jpg ...
# 解析：route_2_011.jpg ...
# 解析：route_2_012.jpg ...
# 解析：route_2_013.jpg ...
# 解析：route_2_014.jpg ...
# 解析：route_2_015.jpg ...
# 解析：route_2_016.jpg ...
# 解析：route_2_017.jpg ...
# 解析：route_2_018.jpg ...
# 解析：route_2_019.jpg ...
# 解析：route_2_020.jpg ...
# 解析：route_2_021.jpg ...
# 解析：route_2_022.jpg ...
# 解析：route_2_023.jpg ...
# 解析：route_2_024.jpg ...
# 解析：route_2_025.jpg ...
# 解析：route_2_026.jpg ...
# 解析：route_2_027.jpg ...
# 解析：route_2_028.jpg ...
# 解析：route_2_029.jpg ...
# 解析：route_2_030.jpg ...
# 解析：route_2_031.jpg ...
# 解析：route_2_032.jpg ...
# 解析：route_2_033.jpg ...
# 解析：route_2_034.jpg ...
# 解析：route_2_035.jpg ...
# 解析：route_2_036.jpg ...
# 解析：route_2_037.jpg ...
# 解析：route_2_038.jpg ...
# 解析：route_2_039.jpg ...
# 解析：route_2_040.jpg ...
# 解析：route_2_041.jpg ...
# 解析：route_2_042.jpg ...
# 解析：route_2_043.jpg ...
# 解析：route_2_044.jpg ...
# 解析：route_2_045.jpg ...
# 解析：route_2_046.jpg ...
# 解析：route_2_047.jpg ...
# 解析：route_2_048.jpg ...
# 解析：route_2_049.jpg ...
# 解析：route_2_050.jpg ...
# 解析：route_2_051.jpg ...
# 解析：route_2_052.jpg ...
# 解析：route_2_053.jpg ...
# 解析：route_2_054.jpg ...
# 解析：route_2_055.jpg ...
# 解析：route_2_056.jpg ...
# 解析：route_2_057.jpg ...
# 解析：route_2_058.jpg ...
# 解析：route_2_059.jpg ...
# 解析：route_2_060.jpg ...
# 解析：route_2_061.jpg ...
# 解析：route_2_062.jpg ...
# 解析：route_2_063.jpg ...
# 解析：route_2_064.jpg ...
# 解析：route_2_065.jpg ...
# 解析：route_2_066.jpg ...
# 解析：route_2_067.jpg ...
# 解析：route_2_068.jpg ...
# 解析：route_2_069.jpg ...
# 解析：route_2_070.jpg ...
# 解析：route_2_071.jpg ...
# 解析：route_2_072.jpg ...
# 解析：route_2_073.jpg ...
# 解析：route_2_074.jpg ...
# 解析：route_2_075.jpg ...
# 解析：route_2_076.jpg ...
# 解析：route_2_077.jpg ...
# 解析：route_2_078.jpg ...
# 解析：route_2_079.jpg ...
# 解析：route_2_080.jpg ...
# 解析：route_2_081.jpg ...
# 解析：route_2_082.jpg ...
# 解析：route_2_083.jpg ...
# 解析：route_2_084.jpg ...
# 解析：route_2_085.jpg ...
# 解析：route_2_086.jpg ...
# 解析：route_2_087.jpg ...
# 解析：route_2_088.jpg ...
# 解析：route_2_089.jpg ...
# 解析：route_2_090.jpg ...
# 解析：route_2_091.jpg ...
# 解析：route_2_092.jpg ...
# 解析：route_2_093.jpg ...
# 解析：route_2_094.jpg ...
# 解析：route_2_095.jpg ...
# 解析：route_3_001.jpg ...
# 解析：route_3_002.jpg ...
# 解析：route_3_003.jpg ...
# 解析：route_3_004.jpg ...
# 解析：route_3_005.jpg ...
# 解析：route_3_006.jpg ...
# 解析：route_3_007.jpg ...
# 解析：route_3_008.jpg ...
# 解析：route_3_009.jpg ...
# 解析：route_3_010.jpg ...
# 解析：route_3_011.jpg ...
# 解析：route_3_012.jpg ...
# 解析：route_3_013.jpg ...
# 解析：route_3_014.jpg ...
# 解析：route_3_015.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_3_015.jpg，跳過
# 解析：route_3_016.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_3_016.jpg，跳過
# 解析：route_3_017.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_3_017.jpg，跳過
# 解析：route_3_018.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_3_018.jpg，跳過
# 解析：route_3_019.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_3_019.jpg，跳過
# 解析：route_3_020.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_3_020.jpg，跳過
# 解析：route_3_021.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_3_021.jpg，跳過
# 解析：route_3_022.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_3_022.jpg，跳過
# 解析：route_3_023.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_3_023.jpg，跳過
# 解析：route_3_024.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_3_024.jpg，跳過
# 解析：route_3_025.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_3_025.jpg，跳過
# 解析：route_3_026.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_3_026.jpg，跳過
# 解析：route_3_027.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_3_027.jpg，跳過
# 解析：route_3_028.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_3_028.jpg，跳過
# 解析：route_3_029.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_3_029.jpg，跳過
# 解析：route_3_030.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_3_030.jpg，跳過
# 解析：route_3_031.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_3_031.jpg，跳過
# 解析：route_3_032.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_3_032.jpg，跳過
# 解析：route_3_033.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_3_033.jpg，跳過
# 解析：route_3_034.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_3_034.jpg，跳過
# 解析：route_4_001.jpg ...
# 解析：route_4_002.jpg ...
# 解析：route_4_003.jpg ...
# 解析：route_4_004.jpg ...
# 解析：route_4_005.jpg ...
# 解析：route_4_006.jpg ...
# 解析：route_4_007.jpg ...
# 解析：route_4_008.jpg ...
# 解析：route_4_009.jpg ...
# 解析：route_4_010.jpg ...
# 解析：route_4_011.jpg ...
# 解析：route_4_012.jpg ...
# 解析：route_4_013.jpg ...
# 解析：route_4_014.jpg ...
# 解析：route_4_015.jpg ...
# 解析：route_4_016.jpg ...
# 解析：route_4_017.jpg ...
# 解析：route_4_018.jpg ...
# 解析：route_4_019.jpg ...
# 解析：route_4_020.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_4_020.jpg，跳過
# 解析：route_4_021.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_4_021.jpg，跳過
# 解析：route_4_022.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_4_022.jpg，跳過
# 解析：route_4_023.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_4_023.jpg，跳過
# 解析：route_4_024.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_4_024.jpg，跳過
# 解析：route_4_025.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_4_025.jpg，跳過
# 解析：route_4_026.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_4_026.jpg，跳過
# 解析：route_4_027.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_4_027.jpg，跳過
# 解析：route_4_028.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_4_028.jpg，跳過
# 解析：route_4_029.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_4_029.jpg，跳過
# 解析：route_4_030.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_4_030.jpg，跳過
# 解析：route_4_031.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_4_031.jpg，跳過
# 解析：route_4_032.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_4_032.jpg，跳過
# 解析：route_4_033.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_4_033.jpg，跳過
# 解析：route_4_034.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_4_034.jpg，跳過
# 解析：route_4_035.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_4_035.jpg，跳過
# 解析：route_4_036.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_4_036.jpg，跳過
# 解析：route_4_037.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_4_037.jpg，跳過
# 解析：route_4_038.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_4_038.jpg，跳過
# 解析：route_4_039.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_4_039.jpg，跳過
# 解析：route_4_040.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_4_040.jpg，跳過
# 解析：route_4_041.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_4_041.jpg，跳過
# 解析：route_4_042.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_4_042.jpg，跳過
# 解析：route_4_043.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_4_043.jpg，跳過
# 解析：route_4_044.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_4_044.jpg，跳過
# 解析：route_4_045.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_4_045.jpg，跳過
# 解析：route_4_046.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_4_046.jpg，跳過
# 解析：route_4_047.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_4_047.jpg，跳過
# 解析：route_4_048.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_4_048.jpg，跳過
# 解析：route_4_049.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_4_049.jpg，跳過
# 解析：route_4_050.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_4_050.jpg，跳過
# 解析：route_4_051.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_4_051.jpg，跳過
# 解析：route_4_052.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_4_052.jpg，跳過
# 解析：route_4_053.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_4_053.jpg，跳過
# 解析：route_4_054.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_4_054.jpg，跳過
# 解析：route_4_055.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_4_055.jpg，跳過
# 解析：route_4_056.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_4_056.jpg，跳過
# 解析：route_4_057.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_4_057.jpg，跳過
# 解析：route_4_058.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_4_058.jpg，跳過
# 解析：route_4_059.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_4_059.jpg，跳過
# 解析：route_4_060.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_4_060.jpg，跳過
# 解析：route_4_061.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_4_061.jpg，跳過
# 解析：route_4_062.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_4_062.jpg，跳過
# 解析：route_4_063.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_4_063.jpg，跳過
# 解析：route_4_064.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_4_064.jpg，跳過
# 解析：route_4_065.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_4_065.jpg，跳過
# 解析：route_4_066.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_4_066.jpg，跳過
# 解析：route_4_067.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_4_067.jpg，跳過
# 解析：route_4_068.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_4_068.jpg，跳過
# 解析：route_4_069.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_4_069.jpg，跳過
# 解析：route_4_070.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_4_070.jpg，跳過
# 解析：route_4_071.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_4_071.jpg，跳過
# 解析：route_4_072.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_4_072.jpg，跳過
# 解析：route_4_073.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_4_073.jpg，跳過
# 解析：route_4_074.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_4_074.jpg，跳過
# 解析：route_4_075.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_4_075.jpg，跳過
# 解析：route_5_001.jpg ...
# 解析：route_5_002.jpg ...
# 解析：route_5_003.jpg ...
# 解析：route_5_004.jpg ...
# 解析：route_5_005.jpg ...
# 解析：route_5_006.jpg ...
# 解析：route_5_007.jpg ...
# 解析：route_5_008.jpg ...
# 解析：route_5_009.jpg ...
# 解析：route_5_010.jpg ...
# 解析：route_5_011.jpg ...
# 解析：route_5_012.jpg ...
# 解析：route_5_013.jpg ...
# 解析：route_5_014.jpg ...
# 解析：route_5_015.jpg ...
# 解析：route_5_016.jpg ...
# 解析：route_5_017.jpg ...
# 解析：route_5_018.jpg ...
# 解析：route_5_019.jpg ...
# 解析：route_5_020.jpg ...
# 解析：route_5_021.jpg ...
# 解析：route_5_022.jpg ...
# 解析：route_5_023.jpg ...
# 解析：route_5_024.jpg ...
# 解析：route_5_025.jpg ...
# 解析：route_5_026.jpg ...
# 解析：route_5_027.jpg ...
# 解析：route_5_028.jpg ...
# 解析：route_5_029.jpg ...
# 解析：route_5_030.jpg ...
# 解析：route_5_031.jpg ...
# 解析：route_5_032.jpg ...
# 解析：route_5_033.jpg ...
# 解析：route_5_034.jpg ...
# 解析：route_5_035.jpg ...
# 解析：route_6_001.jpg ...
# 解析：route_6_002.jpg ...
# 解析：route_6_003.jpg ...
# 解析：route_6_004.jpg ...
# 解析：route_6_005.jpg ...
# 解析：route_6_006.jpg ...
# 解析：route_6_007.jpg ...
# 解析：route_6_008.jpg ...
# 解析：route_6_009.jpg ...
# 解析：route_6_010.jpg ...
# 解析：route_6_011.jpg ...
# 解析：route_6_012.jpg ...
# 解析：route_6_013.jpg ...
# 解析：route_6_014.jpg ...
# 解析：route_6_015.jpg ...
# 解析：route_6_016.jpg ...
# 解析：route_6_017.jpg ...
# 解析：route_6_018.jpg ...
# 解析：route_6_019.jpg ...
# 解析：route_6_020.jpg ...
# 解析：route_6_021.jpg ...
# 解析：route_6_022.jpg ...
# 解析：route_6_023.jpg ...
# 解析：route_6_024.jpg ...
# 解析：route_6_025.jpg ...
# 解析：route_6_026.jpg ...
# 解析：route_6_027.jpg ...
# 解析：route_6_028.jpg ...
# 解析：route_6_029.jpg ...
# 解析：route_6_030.jpg ...
# 解析：route_6_031.jpg ...
# 解析：route_6_032.jpg ...
# 解析：route_6_033.jpg ...
# 解析：route_6_034.jpg ...
# 解析：route_6_035.jpg ...
# 解析：route_6_036.jpg ...
# 解析：route_6_037.jpg ...
# 解析：route_6_038.jpg ...
# 解析：route_6_039.jpg ...
# 解析：route_6_040.jpg ...
# 解析：route_6_041.jpg ...
# 解析：route_6_042.jpg ...
# 解析：route_6_043.jpg ...
# 解析：route_6_044.jpg ...
# 解析：route_6_045.jpg ...
# 解析：route_6_046.jpg ...
# 解析：route_6_047.jpg ...
# 解析：route_6_048.jpg ...
# 解析：route_6_049.jpg ...
# 解析：route_6_050.jpg ...
# 解析：route_6_051.jpg ...
# 解析：route_6_052.jpg ...
# 解析：route_6_053.jpg ...
# 解析：route_6_054.jpg ...
# 解析：route_6_055.jpg ...
# 解析：route_6_056.jpg ...
# 解析：route_6_057.jpg ...
# 解析：route_6_058.jpg ...
# 解析：route_6_059.jpg ...
# 解析：route_6_060.jpg ...
# 解析：route_6_061.jpg ...
# 解析：route_6_062.jpg ...
# 解析：route_6_063.jpg ...
# 解析：route_6_064.jpg ...
# 解析：route_6_065.jpg ...
# 解析：route_6_066.jpg ...
# 解析：route_6_067.jpg ...
# 解析：route_6_068.jpg ...
# 解析：route_6_069.jpg ...
# 解析：route_6_070.jpg ...
# 解析：route_6_071.jpg ...
# 解析：route_6_072.jpg ...
# 解析：route_6_073.jpg ...
# 解析：route_6_074.jpg ...
# 解析：route_6_075.jpg ...
# 解析：route_6_076.jpg ...
# 解析：route_6_077.jpg ...
# 解析：route_6_078.jpg ...
# 解析：route_6_079.jpg ...
# 解析：route_6_080.jpg ...
# 解析：route_6_081.jpg ...
# 解析：route_6_082.jpg ...
# 解析：route_6_083.jpg ...
# 解析：route_6_084.jpg ...
# 解析：route_6_085.jpg ...
# 解析：route_6_086.jpg ...
# 解析：route_6_087.jpg ...
# 解析：route_7_001.jpg ...
# 解析：route_7_002.jpg ...
# 解析：route_7_003.jpg ...
# 解析：route_7_004.jpg ...
# 解析：route_7_005.jpg ...
# 解析：route_7_006.jpg ...
# 解析：route_7_007.jpg ...
# 解析：route_7_008.jpg ...
# 解析：route_7_009.jpg ...
# 解析：route_7_010.jpg ...
# 解析：route_7_011.jpg ...
# 解析：route_7_012.jpg ...
# 解析：route_7_013.jpg ...
# 解析：route_7_014.jpg ...
# 解析：route_7_015.jpg ...
# 解析：route_7_016.jpg ...
# 解析：route_7_017.jpg ...
# 解析：route_7_018.jpg ...
# 解析：route_7_019.jpg ...
# 解析：route_7_020.jpg ...
# 解析：route_7_021.jpg ...
# 解析：route_7_022.jpg ...
# 解析：route_7_023.jpg ...
# 解析：route_7_024.jpg ...
# 解析：route_7_025.jpg ...
# 解析：route_7_026.jpg ...
# 解析：route_7_027.jpg ...
# 解析：route_7_028.jpg ...
# 解析：route_7_029.jpg ...
# 解析：route_7_030.jpg ...
# 解析：route_7_031.jpg ...
# 解析：route_7_032.jpg ...
# 解析：route_7_033.jpg ...
# 解析：route_7_034.jpg ...
# 解析：route_7_035.jpg ...
# 解析：route_7_036.jpg ...
# 解析：route_7_037.jpg ...
# 解析：route_7_038.jpg ...
# 解析：route_7_039.jpg ...
# 解析：route_7_040.jpg ...
# 解析：route_7_041.jpg ...
# 解析：route_7_042.jpg ...
# 解析：route_7_043.jpg ...
# 解析：route_7_044.jpg ...
# 解析：route_7_045.jpg ...
# 解析：route_7_046.jpg ...
# 解析：route_7_047.jpg ...
# 解析：route_7_048.jpg ...
# 解析：route_7_049.jpg ...
# 解析：route_7_050.jpg ...
# 解析：route_7_051.jpg ...
# 解析：route_7_052.jpg ...
# 解析：route_7_053.jpg ...
# 解析：route_7_054.jpg ...
# 解析：route_7_055.jpg ...
# 解析：route_7_056.jpg ...
# 解析：route_7_057.jpg ...
# 解析：route_7_058.jpg ...
# 解析：route_7_059.jpg ...
# 解析：route_7_060.jpg ...
# 解析：route_7_061.jpg ...
# 解析：route_7_062.jpg ...
# 解析：route_7_063.jpg ...
# 解析：route_7_064.jpg ...
# 解析：route_7_065.jpg ...
# 解析：route_7_066.jpg ...
# 解析：route_7_067.jpg ...
# 解析：route_7_068.jpg ...
# 解析：route_7_069.jpg ...
# 解析：route_7_070.jpg ...
# 解析：route_7_071.jpg ...
# 解析：route_7_072.jpg ...
# 解析：route_7_073.jpg ...
# 解析：route_7_074.jpg ...
# 解析：route_7_075.jpg ...
# 解析：route_7_076.jpg ...
# 解析：route_7_077.jpg ...
# 解析：route_7_078.jpg ...
# 解析：route_7_079.jpg ...
# 解析：route_7_080.jpg ...
# 解析：route_7_081.jpg ...
# 解析：route_7_082.jpg ...
# 解析：route_7_083.jpg ...
# 解析：route_7_084.jpg ...
# 解析：route_7_085.jpg ...
# 解析：route_7_086.jpg ...
# 解析：route_7_087.jpg ...
# 解析：route_7_088.jpg ...
# 解析：route_7_089.jpg ...
# 解析：route_7_090.jpg ...
# 解析：route_7_091.jpg ...
# 解析：route_7_092.jpg ...
# 解析：route_7_093.jpg ...
# 解析：route_7_094.jpg ...
# 解析：route_7_095.jpg ...
# 解析：route_7_096.jpg ...
# 解析：route_7_097.jpg ...
# 解析：route_7_098.jpg ...
# 解析：route_7_099.jpg ...
# 解析：route_7_100.jpg ...
# 解析：route_7_101.jpg ...
# 解析：route_7_102.jpg ...
# 解析：route_7_103.jpg ...
# 解析：route_7_104.jpg ...
# 解析：route_7_105.jpg ...
# 解析：route_7_106.jpg ...
# 解析：route_7_107.jpg ...
# 解析：route_7_108.jpg ...
# 解析：route_7_109.jpg ...
# 解析：route_7_110.jpg ...
# 解析：route_7_111.jpg ...
# 解析：route_7_112.jpg ...
# 解析：route_7_113.jpg ...
# 解析：route_7_114.jpg ...
# 解析：route_7_115.jpg ...
# 解析：route_7_116.jpg ...
# 解析：route_7_117.jpg ...
# 解析：route_7_118.jpg ...
# 解析：route_7_119.jpg ...
# 解析：route_7_120.jpg ...
# 解析：route_7_121.jpg ...
# 解析：route_7_122.jpg ...
# 解析：route_7_123.jpg ...
# 解析：route_7_124.jpg ...
# 解析：route_7_125.jpg ...
# 解析：route_7_126.jpg ...
# 解析：route_7_127.jpg ...
# 解析：route_7_128.jpg ...
# 解析：route_7_129.jpg ...
# 解析：route_7_130.jpg ...
# 解析：route_7_131.jpg ...
# 解析：route_7_132.jpg ...
# 解析：route_7_133.jpg ...
# 解析：route_7_134.jpg ...
# 解析：route_7_135.jpg ...
# 解析：route_7_136.jpg ...
# 解析：route_7_137.jpg ...
# 解析：route_7_138.jpg ...
# 解析：route_7_139.jpg ...
# 解析：route_7_140.jpg ...
# 解析：route_7_141.jpg ...
# 解析：route_7_142.jpg ...
# 解析：route_7_143.jpg ...
# 解析：route_7_144.jpg ...
# 解析：route_7_145.jpg ...
# 解析：route_7_146.jpg ...
# 解析：route_7_147.jpg ...
# 解析：route_7_148.jpg ...
# 解析：route_7_149.jpg ...
# 解析：route_7_150.jpg ...
# 解析：route_7_151.jpg ...
# 解析：route_7_152.jpg ...
# 解析：route_7_153.jpg ...
# 解析：route_7_154.jpg ...
# 解析：route_7_155.jpg ...
# 解析：route_7_156.jpg ...
# 解析：route_7_157.jpg ...
# 解析：route_7_158.jpg ...
# 解析：route_7_159.jpg ...
# 解析：route_7_160.jpg ...
# 解析：route_8_001.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_8_001.jpg，跳過
# 解析：route_8_002.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_8_002.jpg，跳過
# 解析：route_8_003.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_8_003.jpg，跳過
# 解析：route_8_004.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_8_004.jpg，跳過
# 解析：route_8_005.jpg ...
# 解析：route_8_006.jpg ...
# 解析：route_8_007.jpg ...
# 解析：route_8_008.jpg ...
# 解析：route_8_009.jpg ...
# 解析：route_8_010.jpg ...
# 解析：route_8_011.jpg ...
# 解析：route_8_012.jpg ...
# 解析：route_8_013.jpg ...
# 解析：route_8_014.jpg ...
# 解析：route_8_015.jpg ...
# 解析：route_8_016.jpg ...
# 解析：route_8_017.jpg ...
# 解析：route_8_018.jpg ...
# 解析：route_8_019.jpg ...
# 解析：route_8_020.jpg ...
# 解析：route_8_021.jpg ...
# 解析：route_8_022.jpg ...
# 解析：route_8_023.jpg ...
# 解析：route_8_024.jpg ...
# 解析：route_8_025.jpg ...
# 解析：route_8_026.jpg ...
# 解析：route_8_027.jpg ...
# 解析：route_8_028.jpg ...
# 解析：route_8_029.jpg ...
# 解析：route_8_030.jpg ...
# 解析：route_8_031.jpg ...
# 解析：route_8_032.jpg ...
# 解析：route_8_033.jpg ...
# 解析：route_8_034.jpg ...
# 解析：route_8_035.jpg ...
# 解析：route_8_036.jpg ...
# 解析：route_8_037.jpg ...
# 解析：route_8_038.jpg ...
# 解析：route_8_039.jpg ...
# 解析：route_8_040.jpg ...
# 解析：route_8_041.jpg ...
# 解析：route_8_042.jpg ...
# 解析：route_8_043.jpg ...
# 解析：route_8_044.jpg ...
# 解析：route_8_045.jpg ...
# 解析：route_8_046.jpg ...
# 解析：route_8_047.jpg ...
# 解析：route_8_048.jpg ...
# 解析：route_8_049.jpg ...
# 解析：route_8_050.jpg ...
# 解析：route_8_051.jpg ...
# 解析：route_8_052.jpg ...
# 解析：route_8_053.jpg ...
# 解析：route_8_054.jpg ...
# 解析：route_8_055.jpg ...
# 解析：route_8_056.jpg ...
# 解析：route_8_057.jpg ...
# 解析：route_8_058.jpg ...
# 解析：route_8_059.jpg ...
# 解析：route_8_060.jpg ...
# 解析：route_8_061.jpg ...
# 解析：route_8_062.jpg ...
# 解析：route_8_063.jpg ...
# 解析：route_8_064.jpg ...
# 解析：route_8_065.jpg ...
# 解析：route_8_066.jpg ...
# 解析：route_8_067.jpg ...
# 解析：route_8_068.jpg ...
# 解析：route_8_069.jpg ...
# 解析：route_8_070.jpg ...
# 解析：route_8_071.jpg ...
# 解析：route_8_072.jpg ...
# 解析：route_8_073.jpg ...
# 解析：route_8_074.jpg ...
# 解析：route_8_075.jpg ...
# 解析：route_8_076.jpg ...
# 解析：route_8_077.jpg ...
# 解析：route_8_078.jpg ...
# 解析：route_8_079.jpg ...
# 解析：route_8_080.jpg ...
# 解析：route_8_081.jpg ...
# 解析：route_8_082.jpg ...
# 解析：route_8_083.jpg ...
# 解析：route_8_084.jpg ...
# 解析：route_8_085.jpg ...
# 解析：route_8_086.jpg ...
# 解析：route_8_087.jpg ...
# 解析：route_8_088.jpg ...
# 解析：route_8_089.jpg ...
# 解析：route_8_090.jpg ...
# 解析：route_8_091.jpg ...
# 解析：route_8_092.jpg ...
# 解析：route_8_093.jpg ...
# 解析：route_8_094.jpg ...
# 解析：route_8_095.jpg ...
# 解析：route_8_096.jpg ...
# 解析：route_8_097.jpg ...
# 解析：route_8_098.jpg ...
# 解析：route_8_099.jpg ...
# 解析：route_8_100.jpg ...
# 解析：route_8_101.jpg ...
# 解析：route_8_102.jpg ...
# 解析：route_8_103.jpg ...
# 解析：route_8_104.jpg ...
# 解析：route_8_105.jpg ...
# 解析：route_8_106.jpg ...
# 解析：route_8_107.jpg ...
# 解析：route_8_108.jpg ...
# 解析：route_8_109.jpg ...
# 解析：route_8_110.jpg ...
# 解析：route_8_111.jpg ...
# 解析：route_8_112.jpg ...
# 解析：route_8_113.jpg ...
# 解析：route_8_114.jpg ...
# 解析：route_8_115.jpg ...
# 解析：route_8_116.jpg ...
# 解析：route_8_117.jpg ...
# 解析：route_9_001.jpg ...
# 解析：route_9_002.jpg ...
# 解析：route_9_003.jpg ...
# 解析：route_9_004.jpg ...
# 解析：route_9_005.jpg ...
# 解析：route_9_006.jpg ...
# 解析：route_9_007.jpg ...
# 解析：route_9_008.jpg ...
# 解析：route_9_009.jpg ...
# 解析：route_9_010.jpg ...
# 解析：route_9_011.jpg ...
# 解析：route_9_012.jpg ...
# 解析：route_9_013.jpg ...
# 解析：route_9_014.jpg ...
# 解析：route_9_015.jpg ...
# 解析：route_9_016.jpg ...
# 解析：route_9_017.jpg ...
# 解析：route_9_018.jpg ...
# 解析：route_9_019.jpg ...
# 解析：route_9_020.jpg ...
# 解析：route_9_021.jpg ...
# 解析：route_9_022.jpg ...
# 解析：route_9_023.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_9_023.jpg，跳過
# 解析：route_9_024.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_9_024.jpg，跳過
# 解析：route_9_025.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_9_025.jpg，跳過
# 解析：route_9_026.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_9_026.jpg，跳過
# 解析：route_9_027.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_9_027.jpg，跳過
# 解析：route_9_028.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_9_028.jpg，跳過
# 解析：route_9_029.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_9_029.jpg，跳過
# 解析：route_9_030.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_9_030.jpg，跳過
# 解析：route_9_031.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_9_031.jpg，跳過
# 解析：route_9_032.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_9_032.jpg，跳過
# 解析：route_9_033.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_9_033.jpg，跳過
# 解析：route_9_034.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_9_034.jpg，跳過
# 解析：route_9_035.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_9_035.jpg，跳過
# 解析：route_9_036.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_9_036.jpg，跳過
# 解析：route_9_037.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_9_037.jpg，跳過
# 解析：route_9_038.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_9_038.jpg，跳過
# 解析：route_9_039.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_9_039.jpg，跳過
# 解析：route_9_040.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_9_040.jpg，跳過
# 解析：route_9_041.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_9_041.jpg，跳過
# 解析：route_9_042.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_9_042.jpg，跳過
# 解析：route_9_043.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_9_043.jpg，跳過
# 解析：route_9_044.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_9_044.jpg，跳過
# 解析：route_9_045.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_9_045.jpg，跳過
# 解析：route_9_046.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_9_046.jpg，跳過
# 解析：route_9_047.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_9_047.jpg，跳過
# 解析：route_9_048.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_9_048.jpg，跳過
# 解析：route_9_049.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_9_049.jpg，跳過
# 解析：route_9_050.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_9_050.jpg，跳過
# 解析：route_9_051.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_9_051.jpg，跳過
# 解析：route_9_052.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_9_052.jpg，跳過
# 解析：route_9_053.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_9_053.jpg，跳過
# 解析：route_9_054.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_9_054.jpg，跳過
# 解析：route_9_055.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_9_055.jpg，跳過
# 解析：route_9_056.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_9_056.jpg，跳過
# 解析：route_9_057.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_9_057.jpg，跳過
# 解析：route_9_058.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_9_058.jpg，跳過
# 解析：route_9_059.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_9_059.jpg，跳過
# 解析：route_9_060.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_9_060.jpg，跳過
# 解析：route_9_061.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_9_061.jpg，跳過
# 解析：route_9_062.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_9_062.jpg，跳過
# 解析：route_9_063.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_9_063.jpg，跳過
# 解析：route_9_064.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_9_064.jpg，跳過
# 解析：route_9_065.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_9_065.jpg，跳過
# 解析：route_9_066.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_9_066.jpg，跳過
# 解析：route_9_067.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_9_067.jpg，跳過
# 解析：route_9_068.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_9_068.jpg，跳過
# 解析：route_9_069.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_9_069.jpg，跳過
# 解析：route_9_070.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_9_070.jpg，跳過
# 解析：route_9_071.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_9_071.jpg，跳過
# 解析：route_9_072.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_9_072.jpg，跳過
# 解析：route_9_073.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_9_073.jpg，跳過
# 解析：route_9_074.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_9_074.jpg，跳過
# 解析：route_9_075.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_9_075.jpg，跳過
# 解析：route_9_076.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_9_076.jpg，跳過
# 解析：route_9_077.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_9_077.jpg，跳過
# 解析：route_9_078.jpg ...
# ⚠ 原始 GeoJSON 找不到 route_9_078.jpg，跳過
#
# ====== 全部街景分析完成 ======
# ✓ 已更新 CSV：streetview_points_with_desc.csv
# ✓ 已更新 GeoJSON：streetview_points_with_desc.geojson
